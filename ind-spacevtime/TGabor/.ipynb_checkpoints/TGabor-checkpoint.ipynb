# %%
from psychopy import visual, event, core
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# Gabor Stimulus 
def ShowImage(image):
    plt.imshow(image, cmap='gray', vmin=-1, vmax=1)
    plt.axis('off') 
    plt.show()

def GaborImage(ori, contrast = 0.2, size=512, sf = 5,noise_mean=0.0, noise_std=0.4):
    x = np.linspace(-1, 1, size)
    y = np.linspace(-1, 1, size)
    X, Y = np.meshgrid(x, y)

    if ori =='left':
        theta = np.deg2rad(-45)
    else:
        theta = np.deg2rad(45)
        
    X_rot = X * np.cos(theta) + Y * np.sin(theta)
    grating = contrast * np.cos(2 * np.pi * sf * X_rot)

    gauss =  np.exp(-(X**2 + Y**2) / (2 * 0.25**2))
    gabor = grating * gauss

    # Normalize to [-1, 1]
    gabor = np.clip(gabor, -1, 1)
    
    low_res_size = size // 2   
    noise_lowres = np.random.normal(
        loc=noise_mean,
        scale=noise_std,
        size=(low_res_size, low_res_size)
    )
    noise = np.repeat(np.repeat(noise_lowres, 2, axis=0), 2, axis=1)
    
    gabor = np.clip(gabor + noise, -1, 1)
    
    return gabor


def GaborMask(ori, size=512, frequency=5, sigma=0.3, noise_mean=0.0, noise_std=2):
    x = np.linspace(-1, 1, size)
    y = np.linspace(-1, 1, size)
    X, Y = np.meshgrid(x, y)

    low_res_size = size // 2   
    noise_lowres = np.random.normal(
        loc=noise_mean,
        scale=noise_std,
        size=(low_res_size, low_res_size)
    )
    noise = np.repeat(np.repeat(noise_lowres, 2, axis=0), 2, axis=1)
    
    return noise

# %%
# Visual Setup

win = visual.Window(size=(1920, 1080), color=0, units="pix", fullscr=True)
stim = visual.ImageStim(win, size=(512, 512), units="pix")

# Parameters
oris = ['left', 'right']
noise_sets = [[0,0,0,0,0], [90,0,90,0,0]]
soa = 0.04
soa_practice = [0.10, 0.15, 0.2]
step_size = 0.005
n_trials = 50
n_practices = 1
noise_gap = 0.05
correct_counter = 0
data = []

# Instruction Screen
text = visual.TextStim(win, text="In this experiment, you will see a grating embedded in noise. The grating will be either up-to-right or up-to-left\
                                        The below one is an up-to-left grating.\
                                        \n\n The grating will be briefly flashed and then immediately masked by some random patterns, your task is to identify whether the grating is up-to-left or up-to-right after it is briefly presented at the center of the screen\
                                        \n\n If you think the grating is up-to-left, press 'x'. If you think the grating is up-to-right, press 'm'.\
                                        \n\n Press SPACE to continue", color=1.0, height=24, pos = (0, 300))
text.draw()
image = visual.ImageStim(image = np.flipud(GaborImage(ori= 'left')), win = win, size=(512, 512), pos = (0, -200), units="pix")
image.draw()
win.flip()
event.waitKeys(keyList=['space'])


# Practice trail screen
text = visual.TextStim(win, text="We will begin with several practice trials, feedback on correctness will be provided after each trial.\
                                \n\n If you think the grating is up-to-left, press 'x'. If you think the grating is up-to-right, press 'm'.\
                                \n\n Press SPACE to start the practice trials. ", color=1.0, height=24)
text.draw()
win.flip()
event.waitKeys(keyList=['space'])

for trial in range(n_practices):
    if 'escape' in event.getKeys():
        print("Experiment aborted by user.")
        break

    # Fixation
    fixation = visual.TextStim(win, text="+", color=1.0, height=48)
    fixation.draw()
    win.flip()
    core.wait(0.5)

    # Stimulus
    ori, practice_soa = random.choice(oris), random.choice(soa_practice)
    stim.image = np.flipud(GaborImage(ori = ori))
    stim.draw()
    win.flip()
    core.wait(practice_soa)

    
    noise_set = random.choice(noise_sets)  
    for noise_ori in noise_set:
        stim.image = np.flipud(GaborMask(noise_ori))
        stim.draw()
        win.flip()
        core.wait(noise_gap)
        

    # Decision
    wait = visual.TextStim(win, text="Choose the orientation", color=1.0, height=48)
    wait.draw()
    win.flip()
    keys = event.waitKeys(keyList=['x','m'] + ['escape'])
    if 'escape' in keys:
        print("Experiment aborted by user.")
        break

    response = 'left' if keys[0] == 'x' else 'right'
    correct = response == ori

    # Feedback 
    if correct:
        feedback_text = "Correct!"
        feedback_color = 'green'
    else:
        feedback_text = 'Wrong!'
        feedback_color = 'red'
    
    feedback = visual.TextStim(win, text=feedback_text, color=feedback_color, height=36)
    feedback.draw()
    win.flip()
    core.wait(0.5)  
    win.flip()
    core.wait(0.5)


# --- Main Staircase Block ---
text = visual.TextStim(win, text="Excellent! Here comes the main experiment. This time the task is more difficult, please pay attention\
                                \n\n If you think the grating is up-to-left, press 'x'. If you think the grating is up-to-right, press 'm'.\
                                \n\n Press SPACE to start the main experiment. ", color=1.0, height=34)
text.draw()
win.flip()
event.waitKeys(keyList=['space'])

for trial in range(n_trials):
    if 'escape' in event.getKeys():
        print("Experiment aborted by user.")
        break

    # Fixation
    fixation = visual.TextStim(win, text="+", color=1.0, height=48)
    fixation.draw()
    win.flip()
    core.wait(0.5)

    # Stimulus
    ori = random.choice(oris)
    stim.image = np.flipud(GaborImage(ori = ori))
    stim.draw()
    win.flip()
    core.wait(soa)
    
    noise_set = random.choice(noise_sets)  
    for noise_ori in noise_set:
        stim.image = np.flipud(GaborMask(noise_ori))
        stim.draw()
        win.flip()
        core.wait(noise_gap)
        
    # Decision
    wait = visual.TextStim(win, text="Choose the orientation", color=1.0, height=48)
    wait.draw()
    win.flip()
    keys = event.waitKeys(keyList=['x', 'm', 'escape'])
    if 'escape' in keys:
        print("Experiment aborted by user.")
        break
    win.flip()
    
    response = 'left' if keys[0] == 'x' else 'right'
    correct = response == ori
    data.append({"trial": trial+1, "orientation": ori, "response": response,
                 "correct": correct, "soa": soa})
    if correct:
        correct_counter += 1
        if correct_counter == 2:
            soa = max(0, soa - step_size)
            correct_counter = 0
    else:
        soa = min(1.0, soa + step_size)
        correct_counter = 0
    core.wait(0.5)
    print(soa)



# Cleanup 
win.close()
 
# ---------- Plot ----------
soas = [d["soa"] for d in data]
plt.figure(figsize=(8, 4)) 
plt.plot(range(1, n_trials + 1), soas, marker='o')
plt.xlabel("Trial")
plt.ylabel("Alpha (Visibility)")
plt.title("2-Down-1-Up Staircase")
plt.grid(True)
plt.show()
 
# Optional: save data
import pandas as pd
df = pd.DataFrame(data)
df.to_csv("Results.csv", index=False)
# Out:
# 0.04
# 0.035
# 0.035
# 0.030000000000000002
# 0.030000000000000002
# 0.025
# 0.025
# 0.02
# Experiment aborted by user.
# 81548.9941 	WARNING 	Monitor specification not found. Creating a temporary one...
# 81549.0583 	WARNING 	User requested fullscreen with size [1920 1080], but screen is actually [3440, 1440]. Using actual size
# 81551.9088 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81552.0047 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81552.1005 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81552.1944 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81552.2905 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81555.0254 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81555.1149 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81555.2055 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81555.2945 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81555.3759 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81557.0657 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81557.1479 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81557.2362 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81557.3277 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81557.4164 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81559.3707 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81559.4554 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81559.5380 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81559.6281 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81559.7174 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81560.9413 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81561.0284 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81561.1182 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81561.2064 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81561.2887 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81562.5881 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81562.6812 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81562.7679 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81562.8618 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81562.9489 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81564.2661 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81564.3494 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81564.4407 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81564.5275 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81564.6210 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81565.8413 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81565.9265 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81566.0169 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81566.1114 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81566.1998 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81567.5021 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81567.5973 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81567.6878 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81567.7784 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81567.8697 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81569.0876 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81569.1767 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81569.2609 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81569.3593 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# 81569.4467 	ERROR 	numpy arrays used as textures should be in the range -1(black):1(white)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 160
#     158 soas = [d["soa"] for d in data]
#     159 plt.figure(figsize=(8, 4))
# --> 160 plt.plot(range(1, n_trials + 1), soas, marker='o')
#     161 plt.xlabel("Trial")
#     162 plt.ylabel("Alpha (Visibility)")
#
# File ~\anaconda3\envs\psychopy-env\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\envs\psychopy-env\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~\anaconda3\envs\psychopy-env\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\envs\psychopy-env\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (50,) and (8,)
